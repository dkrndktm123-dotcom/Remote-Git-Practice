# %% [markdown]
# # 합성곱 신경망

# %%
import os
os.environ["KERAS_BACKEND"] = "jax"

# %%
# @title
import os
from IPython.core.magic import register_cell_magic

@register_cell_magic
def backend(line, cell):
    current, required = os.environ.get("KERAS_BACKEND", ""), line.split()[-1]
    if current == required:
        get_ipython().run_cell(cell)
    else:
        print(
            f"This cell requires the {required} backend. To run it, change KERAS_BACKEND to "
            f"\"{required}\" at the top of the notebook, restart the runtime, and rerun the notebook."
        )

# %% [markdown]
# ## 합성곱 신경망 소개

# %% [markdown]
# **예제: MNIST 데이터셋 분류 CNN 모델**

# %%
import keras
from keras import layers

inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(inputs)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.GlobalAveragePooling2D()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %% [markdown]
# **모델 구성 요약**

# %%
model.summary(line_length=80)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                      ┃ Output Shape             ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)          │ (None, 28, 28, 1)        │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                   │ (None, 26, 26, 64)       │           640 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)      │ (None, 13, 13, 64)       │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)                 │ (None, 11, 11, 128)      │        73,856 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)    │ (None, 5, 5, 128)        │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)                 │ (None, 3, 3, 256)        │       295,168 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ global_average_pooling2d          │ (None, 256)              │             0 │
# │ (GlobalAveragePooling2D)          │                          │               │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ dense (Dense)                     │ (None, 10)               │         2,570 │
# └───────────────────────────────────┴──────────────────────────┴───────────────┘
#  Total params: 372,234 (1.42 MB)
#  Trainable params: 372,234 (1.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **MNIST 이미지 분류 훈련**
#
# 모델 훈련은 이전과 동일하다.

# %% [markdown]
# - 훈련셋 준비

# %%
from keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype("float32") / 255
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# - 모델 컴파일과 훈련

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

model.fit(train_images, train_labels, epochs=5, batch_size=64)
# Out:
# Epoch 1/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9231 - loss: 0.2496
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9774 - loss: 0.0731
# Epoch 3/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9846 - loss: 0.0491
# Epoch 4/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9886 - loss: 0.0365
# Epoch 5/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9915 - loss: 0.0283

# %% [markdown]
# **훈련된 CNN 평가**
#
# 테스트셋에 대한 성능이 이전에 사용한 `Sequential` 모델보다 훨씬 좋다.

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9904 - loss: 0.0320
# Test accuracy: 0.990

# %% [markdown]
# #### The convolution operation

# %% [markdown]
# ##### Understanding border effects and padding

# %% [markdown]
# ##### Understanding convolution strides

# %% [markdown]
# #### The max-pooling operation

# %%
inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(inputs)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.GlobalAveragePooling2D()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model_no_max_pool = keras.Model(inputs=inputs, outputs=outputs)

# %%
model_no_max_pool.summary(line_length=80)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                      ┃ Output Shape             ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)        │ (None, 28, 28, 1)        │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)                 │ (None, 26, 26, 64)       │           640 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)                 │ (None, 24, 24, 128)      │        73,856 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)                 │ (None, 22, 22, 256)      │       295,168 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ global_average_pooling2d_1        │ (None, 256)              │             0 │
# │ (GlobalAveragePooling2D)          │                          │               │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ dense_1 (Dense)                   │ (None, 10)               │         2,570 │
# └───────────────────────────────────┴──────────────────────────┴───────────────┘
#  Total params: 372,234 (1.42 MB)
#  Trainable params: 372,234 (1.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Training a ConvNet from scratch on a small dataset

# %% [markdown]
# #### The relevance of deep learning for small-data problems

# %% [markdown]
# #### Downloading the data

# %%
import kagglehub

kagglehub.login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://www.kaggle.com/static/images/site-logo.png\nalt=\'Kaggle…
# Kaggle credentials set.
# Kaggle credentials successfully validated.

# %%
download_path = kagglehub.competition_download("dogs-vs-cats")
# Out:
# Downloading to /root/.cache/kagglehub/competitions/dogs-vs-cats.archive...
# 100%|██████████| 812M/812M [00:07<00:00, 112MB/s]
# Extracting files...

# %%
import zipfile

with zipfile.ZipFile(download_path + "/train.zip", "r") as zip_ref:
    zip_ref.extractall(".")

# %%
import os, shutil, pathlib

original_dir = pathlib.Path("train")
new_base_dir = pathlib.Path("dogs_vs_cats_small")

def make_subset(subset_name, start_index, end_index):
    for category in ("cat", "dog"):
        dir = new_base_dir / subset_name / category
        os.makedirs(dir)
        fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
        for fname in fnames:
            shutil.copyfile(src=original_dir / fname, dst=dir / fname)

make_subset("train", start_index=0, end_index=1000)
make_subset("validation", start_index=1000, end_index=1500)
make_subset("test", start_index=1500, end_index=2500)

# %% [markdown]
# #### Building your model

# %%
import keras
from keras import layers

inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1.0 / 255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=512, kernel_size=3, activation="relu")(x)
x = layers.GlobalAveragePooling2D()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary(line_length=80)
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                      ┃ Output Shape             ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)        │ (None, 180, 180, 3)      │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ rescaling (Rescaling)             │ (None, 180, 180, 3)      │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)                 │ (None, 178, 178, 32)     │           896 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)    │ (None, 89, 89, 32)       │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)                 │ (None, 87, 87, 64)       │        18,496 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)    │ (None, 43, 43, 64)       │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)                 │ (None, 41, 41, 128)      │        73,856 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)    │ (None, 20, 20, 128)      │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)                 │ (None, 18, 18, 256)      │       295,168 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)    │ (None, 9, 9, 256)        │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)                │ (None, 7, 7, 512)        │     1,180,160 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ global_average_pooling2d_2        │ (None, 512)              │             0 │
# │ (GlobalAveragePooling2D)          │                          │               │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ dense_2 (Dense)                   │ (None, 1)                │           513 │
# └───────────────────────────────────┴──────────────────────────┴───────────────┘
#  Total params: 1,569,089 (5.99 MB)
#  Trainable params: 1,569,089 (5.99 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"],
)

# %% [markdown]
# #### Data preprocessing

# %%
from keras.utils import image_dataset_from_directory

batch_size = 64
image_size = (180, 180)
train_dataset = image_dataset_from_directory(
    new_base_dir / "train", image_size=image_size, batch_size=batch_size
)
validation_dataset = image_dataset_from_directory(
    new_base_dir / "validation", image_size=image_size, batch_size=batch_size
)
test_dataset = image_dataset_from_directory(
    new_base_dir / "test", image_size=image_size, batch_size=batch_size
)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 2000 files belonging to 2 classes.

# %% [markdown]
# ##### Understanding TensorFlow Dataset objects

# %%
import numpy as np
import tensorflow as tf

random_numbers = np.random.normal(size=(1000, 16))
dataset = tf.data.Dataset.from_tensor_slices(random_numbers)

# %%
for i, element in enumerate(dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (16,)
# (16,)
# (16,)

# %%
batched_dataset = dataset.batch(32)
for i, element in enumerate(batched_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (32, 16)
# (32, 16)
# (32, 16)

# %%
reshaped_dataset = dataset.map(
    lambda x: tf.reshape(x, (4, 4)),
    num_parallel_calls=8)
for i, element in enumerate(reshaped_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (4, 4)
# (4, 4)
# (4, 4)

# %% [markdown]
# ##### Fitting the model

# %%
for data_batch, labels_batch in train_dataset:
    print("data batch shape:", data_batch.shape)
    print("labels batch shape:", labels_batch.shape)
    break
# Out:
# data batch shape: (64, 180, 180, 3)
# labels batch shape: (64,)

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]
history = model.fit(
    train_dataset,
    epochs=50,
    validation_data=validation_dataset,
    callbacks=callbacks,
)
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 18s 348ms/step - accuracy: 0.5120 - loss: 0.6976 - val_accuracy: 0.5220 - val_loss: 0.6919
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - accuracy: 0.5290 - loss: 0.6885 - val_accuracy: 0.5820 - val_loss: 0.6733
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 171ms/step - accuracy: 0.6015 - loss: 0.6699 - val_accuracy: 0.5930 - val_loss: 0.6519
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 129ms/step - accuracy: 0.6230 - loss: 0.6430 - val_accuracy: 0.6690 - val_loss: 0.6204
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - accuracy: 0.6645 - loss: 0.6149 - val_accuracy: 0.6770 - val_loss: 0.5990
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 175ms/step - accuracy: 0.6485 - loss: 0.6256 - val_accuracy: 0.6790 - val_loss: 0.6047
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - accuracy: 0.6895 - loss: 0.5918 - val_accuracy: 0.6990 - val_loss: 0.5746
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - accuracy: 0.7290 - loss: 0.5628 - val_accuracy: 0.7210 - val_loss: 0.5555
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.7045 - loss: 0.5710 - val_accuracy: 0.7180 - val_loss: 0.5608
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.7400 - loss: 0.5343 - val_accuracy: 0.6920 - val_loss: 0.5865
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - accuracy: 0.7325 - loss: 0.5479 - val_accuracy: 0.7520 - val_loss: 0.5279
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 141ms/step - accuracy: 0.7610 - loss: 0.5146 - val_accuracy: 0.7210 - val_loss: 0.5504
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - accuracy: 0.7320 - loss: 0.5295 - val_accuracy: 0.7440 - val_loss: 0.5305
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - accuracy: 0.7650 - loss: 0.4918 - val_accuracy: 0.7280 - val_loss: 0.5504
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.7705 - loss: 0.4852 - val_accuracy: 0.7320 - val_loss: 0.5586
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - accuracy: 0.8010 - loss: 0.4483 - val_accuracy: 0.7220 - val_loss: 0.6133
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - accuracy: 0.8005 - loss: 0.4447 - val_accuracy: 0.7540 - val_loss: 0.5094
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - accuracy: 0.7910 - loss: 0.4533 - val_accuracy: 0.6030 - val_loss: 0.7831
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - accuracy: 0.7710 - loss: 0.4933 - val_accuracy: 0.7500 - val_loss: 0.5168
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - accuracy: 0.8225 - loss: 0.4054 - val_accuracy: 0.7550 - val_loss: 0.5353
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 179ms/step - accuracy: 0.8280 - loss: 0.3936 - val_accuracy: 0.7760 - val_loss: 0.4813
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - accuracy: 0.8565 - loss: 0.3350 - val_accuracy: 0.7460 - val_loss: 0.6064
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - accuracy: 0.8630 - loss: 0.3212 - val_accuracy: 0.7880 - val_loss: 0.4749
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.8765 - loss: 0.3009 - val_accuracy: 0.7930 - val_loss: 0.5398
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - accuracy: 0.8835 - loss: 0.2612 - val_accuracy: 0.8070 - val_loss: 0.5074
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - accuracy: 0.9140 - loss: 0.2145 - val_accuracy: 0.7720 - val_loss: 0.7469
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 142ms/step - accuracy: 0.9075 - loss: 0.2137 - val_accuracy: 0.7900 - val_loss: 0.5549
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 128ms/step - accuracy: 0.9000 - loss: 0.2389 - val_accuracy: 0.7500 - val_loss: 0.6853
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - accuracy: 0.9300 - loss: 0.1818 - val_accuracy: 0.8190 - val_loss: 0.6008
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 132ms/step - accuracy: 0.9365 - loss: 0.1592 - val_accuracy: 0.8060 - val_loss: 0.5652
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.9490 - loss: 0.1362 - val_accuracy: 0.8220 - val_loss: 0.5996
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - accuracy: 0.9660 - loss: 0.1031 - val_accuracy: 0.7970 - val_loss: 0.6924
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9635 - loss: 0.1053 - val_accuracy: 0.8010 - val_loss: 0.6904
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.9280 - loss: 0.1651 - val_accuracy: 0.8040 - val_loss: 0.5812
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - accuracy: 0.9720 - loss: 0.0861 - val_accuracy: 0.8180 - val_loss: 0.6243
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 141ms/step - accuracy: 0.9835 - loss: 0.0490 - val_accuracy: 0.8050 - val_loss: 0.7727
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - accuracy: 0.9890 - loss: 0.0430 - val_accuracy: 0.7930 - val_loss: 0.9049
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - accuracy: 0.9585 - loss: 0.1112 - val_accuracy: 0.7550 - val_loss: 1.1257
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - accuracy: 0.9685 - loss: 0.0910 - val_accuracy: 0.7900 - val_loss: 0.8777
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - accuracy: 0.9825 - loss: 0.0522 - val_accuracy: 0.8150 - val_loss: 0.7861
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - accuracy: 0.9945 - loss: 0.0268 - val_accuracy: 0.8230 - val_loss: 0.7939
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.9870 - loss: 0.0345 - val_accuracy: 0.7750 - val_loss: 1.1946
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 127ms/step - accuracy: 0.8645 - loss: 0.3678 - val_accuracy: 0.7910 - val_loss: 0.6131
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - accuracy: 0.9720 - loss: 0.0900 - val_accuracy: 0.8180 - val_loss: 0.6777
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 178ms/step - accuracy: 0.9925 - loss: 0.0370 - val_accuracy: 0.8160 - val_loss: 0.7935
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - accuracy: 0.9935 - loss: 0.0252 - val_accuracy: 0.8090 - val_loss: 0.8834
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - accuracy: 0.9910 - loss: 0.0270 - val_accuracy: 0.8170 - val_loss: 0.8688
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.9980 - loss: 0.0143 - val_accuracy: 0.8150 - val_loss: 0.9250
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - accuracy: 0.9990 - loss: 0.0067 - val_accuracy: 0.8180 - val_loss: 0.9559
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - accuracy: 0.9995 - loss: 0.0044 - val_accuracy: 0.8200 - val_loss: 0.9908

# %%
import matplotlib.pyplot as plt

accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)

plt.plot(epochs, accuracy, "r--", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()

plt.plot(epochs, loss, "r--", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
test_model = keras.models.load_model("convnet_from_scratch.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.8010 - loss: 0.4770
# Test accuracy: 0.801

# %% [markdown]
# #### Using data augmentation

# %%
data_augmentation_layers = [
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.2),
]

def data_augmentation(images, targets):
    for layer in data_augmentation_layers:
        images = layer(images)
    return images, targets

augmented_train_dataset = train_dataset.map(
    data_augmentation, num_parallel_calls=8
)
augmented_train_dataset = augmented_train_dataset.prefetch(tf.data.AUTOTUNE)

# %%
plt.figure(figsize=(10, 10))
for image_batch, _ in train_dataset.take(1):
    image = image_batch[0]
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        augmented_image, _ = data_augmentation(image, None)
        augmented_image = keras.ops.convert_to_numpy(augmented_image)
        plt.imshow(augmented_image.astype("uint8"))
        plt.axis("off")

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1.0 / 255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=512, kernel_size=3, activation="relu")(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.25)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"],
)

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch_with_augmentation.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]
history = model.fit(
    augmented_train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks,
)
# Out:
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 408ms/step - accuracy: 0.5070 - loss: 0.6980 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 425ms/step - accuracy: 0.4950 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6922
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 436ms/step - accuracy: 0.5255 - loss: 0.6905 - val_accuracy: 0.5540 - val_loss: 0.6838
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 434ms/step - accuracy: 0.5420 - loss: 0.6900 - val_accuracy: 0.5180 - val_loss: 0.6901
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 411ms/step - accuracy: 0.5335 - loss: 0.6902 - val_accuracy: 0.5660 - val_loss: 0.6836
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 443ms/step - accuracy: 0.5535 - loss: 0.6765 - val_accuracy: 0.5790 - val_loss: 0.6585
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 436ms/step - accuracy: 0.6140 - loss: 0.6555 - val_accuracy: 0.5610 - val_loss: 0.6824
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 428ms/step - accuracy: 0.6145 - loss: 0.6435 - val_accuracy: 0.6290 - val_loss: 0.6484
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 433ms/step - accuracy: 0.6440 - loss: 0.6279 - val_accuracy: 0.6590 - val_loss: 0.6211
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 426ms/step - accuracy: 0.6265 - loss: 0.6357 - val_accuracy: 0.6660 - val_loss: 0.6128
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 436ms/step - accuracy: 0.6710 - loss: 0.6135 - val_accuracy: 0.6870 - val_loss: 0.5944
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 428ms/step - accuracy: 0.6790 - loss: 0.6040 - val_accuracy: 0.6810 - val_loss: 0.5928
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 431ms/step - accuracy: 0.6645 - loss: 0.6042 - val_accuracy: 0.6590 - val_loss: 0.6246
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 437ms/step - accuracy: 0.6810 - loss: 0.5960 - val_accuracy: 0.7110 - val_loss: 0.5667
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 444ms/step - accuracy: 0.6835 - loss: 0.5879 - val_accuracy: 0.5990 - val_loss: 0.6854
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 19s 400ms/step - accuracy: 0.6835 - loss: 0.6056 - val_accuracy: 0.6830 - val_loss: 0.5952
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 434ms/step - accuracy: 0.7010 - loss: 0.5736 - val_accuracy: 0.6730 - val_loss: 0.5995
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 420ms/step - accuracy: 0.7060 - loss: 0.5667 - val_accuracy: 0.7150 - val_loss: 0.5540
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 418ms/step - accuracy: 0.7060 - loss: 0.5730 - val_accuracy: 0.6990 - val_loss: 0.5757
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 427ms/step - accuracy: 0.7030 - loss: 0.5716 - val_accuracy: 0.7290 - val_loss: 0.5432
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 425ms/step - accuracy: 0.7210 - loss: 0.5640 - val_accuracy: 0.7400 - val_loss: 0.5346
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 419ms/step - accuracy: 0.7155 - loss: 0.5545 - val_accuracy: 0.7200 - val_loss: 0.5472
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 411ms/step - accuracy: 0.7155 - loss: 0.5591 - val_accuracy: 0.7040 - val_loss: 0.5794
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 411ms/step - accuracy: 0.7175 - loss: 0.5614 - val_accuracy: 0.7260 - val_loss: 0.5403
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 413ms/step - accuracy: 0.7255 - loss: 0.5445 - val_accuracy: 0.7060 - val_loss: 0.5667
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 420ms/step - accuracy: 0.7190 - loss: 0.5436 - val_accuracy: 0.7280 - val_loss: 0.5423
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 421ms/step - accuracy: 0.7245 - loss: 0.5318 - val_accuracy: 0.7430 - val_loss: 0.5312
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 436ms/step - accuracy: 0.7280 - loss: 0.5407 - val_accuracy: 0.7380 - val_loss: 0.5364
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 427ms/step - accuracy: 0.7430 - loss: 0.5180 - val_accuracy: 0.7510 - val_loss: 0.5107
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 423ms/step - accuracy: 0.7605 - loss: 0.5028 - val_accuracy: 0.7350 - val_loss: 0.5266
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 420ms/step - accuracy: 0.7715 - loss: 0.4786 - val_accuracy: 0.7510 - val_loss: 0.4912
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 433ms/step - accuracy: 0.7665 - loss: 0.4828 - val_accuracy: 0.7720 - val_loss: 0.4688
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 410ms/step - accuracy: 0.7790 - loss: 0.4699 - val_accuracy: 0.7250 - val_loss: 0.5459
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 426ms/step - accuracy: 0.7790 - loss: 0.4639 - val_accuracy: 0.7670 - val_loss: 0.4642
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 430ms/step - accuracy: 0.7585 - loss: 0.4999 - val_accuracy: 0.7770 - val_loss: 0.4707
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 411ms/step - accuracy: 0.7850 - loss: 0.4606 - val_accuracy: 0.7770 - val_loss: 0.4511
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 422ms/step - accuracy: 0.8050 - loss: 0.4206 - val_accuracy: 0.7720 - val_loss: 0.4884
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 432ms/step - accuracy: 0.7930 - loss: 0.4386 - val_accuracy: 0.7900 - val_loss: 0.4360
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 419ms/step - accuracy: 0.7990 - loss: 0.4252 - val_accuracy: 0.7930 - val_loss: 0.4527
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 431ms/step - accuracy: 0.7670 - loss: 0.4839 - val_accuracy: 0.7810 - val_loss: 0.4578
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 420ms/step - accuracy: 0.8135 - loss: 0.4089 - val_accuracy: 0.7240 - val_loss: 0.6085
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 428ms/step - accuracy: 0.8265 - loss: 0.4050 - val_accuracy: 0.7980 - val_loss: 0.4289
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 434ms/step - accuracy: 0.8360 - loss: 0.3801 - val_accuracy: 0.8070 - val_loss: 0.4237
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 428ms/step - accuracy: 0.8365 - loss: 0.3638 - val_accuracy: 0.8170 - val_loss: 0.4248
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 425ms/step - accuracy: 0.8455 - loss: 0.3705 - val_accuracy: 0.8150 - val_loss: 0.4286
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 428ms/step - accuracy: 0.8245 - loss: 0.3872 - val_accuracy: 0.7940 - val_loss: 0.4433
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 430ms/step - accuracy: 0.8430 - loss: 0.3545 - val_accuracy: 0.8110 - val_loss: 0.3903
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 424ms/step - accuracy: 0.8435 - loss: 0.3536 - val_accuracy: 0.8270 - val_loss: 0.3955
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 420ms/step - accuracy: 0.8395 - loss: 0.3420 - val_accuracy: 0.7930 - val_loss: 0.4588
# Epoch 50/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 436ms/step - accuracy: 0.8400 - loss: 0.3476 - val_accuracy: 0.8170 - val_loss: 0.4257
# Epoch 51/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 425ms/step - accuracy: 0.8455 - loss: 0.3421 - val_accuracy: 0.8340 - val_loss: 0.4000
# Epoch 52/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 416ms/step - accuracy: 0.8615 - loss: 0.3305 - val_accuracy: 0.8210 - val_loss: 0.4149
# Epoch 53/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 439ms/step - accuracy: 0.8700 - loss: 0.3164 - val_accuracy: 0.8340 - val_loss: 0.3995
# Epoch 54/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 416ms/step - accuracy: 0.8710 - loss: 0.3177 - val_accuracy: 0.7780 - val_loss: 0.5970
# Epoch 55/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 422ms/step - accuracy: 0.8515 - loss: 0.3315 - val_accuracy: 0.8270 - val_loss: 0.4329
# Epoch 56/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 401ms/step - accuracy: 0.8670 - loss: 0.3163 - val_accuracy: 0.8010 - val_loss: 0.4842
# Epoch 57/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 420ms/step - accuracy: 0.8685 - loss: 0.3042 - val_accuracy: 0.7900 - val_loss: 0.5211
# Epoch 58/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 431ms/step - accuracy: 0.8570 - loss: 0.3264 - val_accuracy: 0.8330 - val_loss: 0.3836
# Epoch 59/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 434ms/step - accuracy: 0.8735 - loss: 0.2945 - val_accuracy: 0.8420 - val_loss: 0.4018
# Epoch 60/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 425ms/step - accuracy: 0.8705 - loss: 0.2898 - val_accuracy: 0.8470 - val_loss: 0.3710
# Epoch 61/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 427ms/step - accuracy: 0.8845 - loss: 0.2711 - val_accuracy: 0.8550 - val_loss: 0.3634
# Epoch 62/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 424ms/step - accuracy: 0.8800 - loss: 0.2765 - val_accuracy: 0.8440 - val_loss: 0.4003
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 441ms/step - accuracy: 0.8975 - loss: 0.2375 - val_accuracy: 0.8360 - val_loss: 0.4861
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 407ms/step - accuracy: 0.8925 - loss: 0.2543 - val_accuracy: 0.8380 - val_loss: 0.4291
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 432ms/step - accuracy: 0.8900 - loss: 0.2718 - val_accuracy: 0.8390 - val_loss: 0.4078
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 510ms/step - accuracy: 0.8915 - loss: 0.2423 - val_accuracy: 0.8670 - val_loss: 0.3829
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 18s 425ms/step - accuracy: 0.9115 - loss: 0.2269 - val_accuracy: 0.7600 - val_loss: 0.9326
# Epoch 68/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 430ms/step - accuracy: 0.8610 - loss: 0.3287 - val_accuracy: 0.8470 - val_loss: 0.3912
# Epoch 69/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 430ms/step - accuracy: 0.9060 - loss: 0.2388 - val_accuracy: 0.8430 - val_loss: 0.4087
# Epoch 70/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 430ms/step - accuracy: 0.8985 - loss: 0.2335 - val_accuracy: 0.8510 - val_loss: 0.4212
# Epoch 71/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 406ms/step - accuracy: 0.8980 - loss: 0.2209 - val_accuracy: 0.8330 - val_loss: 0.4895
# Epoch 72/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 441ms/step - accuracy: 0.9015 - loss: 0.2361 - val_accuracy: 0.8590 - val_loss: 0.4365
# Epoch 73/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 443ms/step - accuracy: 0.9125 - loss: 0.2060 - val_accuracy: 0.8640 - val_loss: 0.3972
# Epoch 74/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 444ms/step - accuracy: 0.9150 - loss: 0.2083 - val_accuracy: 0.8480 - val_loss: 0.4846
# Epoch 75/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 428ms/step - accuracy: 0.9135 - loss: 0.2168 - val_accuracy: 0.8620 - val_loss: 0.4056
# Epoch 76/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 410ms/step - accuracy: 0.9190 - loss: 0.2024 - val_accuracy: 0.8260 - val_loss: 0.5908
# Epoch 77/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 448ms/step - accuracy: 0.9085 - loss: 0.2230 - val_accuracy: 0.8490 - val_loss: 0.3930
# Epoch 78/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 19s 424ms/step - accuracy: 0.9165 - loss: 0.1904 - val_accuracy: 0.8350 - val_loss: 0.4964
# Epoch 79/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 421ms/step - accuracy: 0.9175 - loss: 0.1942 - val_accuracy: 0.8590 - val_loss: 0.4486
# Epoch 80/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 430ms/step - accuracy: 0.9220 - loss: 0.1933 - val_accuracy: 0.8660 - val_loss: 0.3828
# Epoch 81/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 415ms/step - accuracy: 0.9315 - loss: 0.1826 - val_accuracy: 0.8560 - val_loss: 0.4787
# Epoch 82/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 417ms/step - accuracy: 0.9235 - loss: 0.1823 - val_accuracy: 0.8310 - val_loss: 0.4895
# Epoch 83/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 417ms/step - accuracy: 0.9230 - loss: 0.1835 - val_accuracy: 0.8610 - val_loss: 0.4459
# Epoch 84/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 419ms/step - accuracy: 0.9355 - loss: 0.1581 - val_accuracy: 0.8620 - val_loss: 0.4392
# Epoch 85/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 417ms/step - accuracy: 0.9200 - loss: 0.2006 - val_accuracy: 0.8450 - val_loss: 0.4046
# Epoch 86/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 411ms/step - accuracy: 0.9270 - loss: 0.1647 - val_accuracy: 0.8360 - val_loss: 0.5160
# Epoch 87/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 440ms/step - accuracy: 0.9270 - loss: 0.1701 - val_accuracy: 0.8230 - val_loss: 0.6933
# Epoch 88/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 19s 422ms/step - accuracy: 0.9195 - loss: 0.1995 - val_accuracy: 0.8750 - val_loss: 0.3433
# Epoch 89/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 414ms/step - accuracy: 0.9410 - loss: 0.1625 - val_accuracy: 0.8620 - val_loss: 0.4152
# Epoch 90/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 415ms/step - accuracy: 0.9430 - loss: 0.1422 - val_accuracy: 0.8400 - val_loss: 0.7160
# Epoch 91/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 418ms/step - accuracy: 0.9270 - loss: 0.1788 - val_accuracy: 0.8570 - val_loss: 0.4799
# Epoch 92/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 399ms/step - accuracy: 0.9290 - loss: 0.1720 - val_accuracy: 0.8550 - val_loss: 0.4788
# Epoch 93/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 419ms/step - accuracy: 0.9365 - loss: 0.1610 - val_accuracy: 0.8650 - val_loss: 0.3902
# Epoch 94/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 422ms/step - accuracy: 0.9290 - loss: 0.1594 - val_accuracy: 0.8570 - val_loss: 0.4224
# Epoch 95/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 414ms/step - accuracy: 0.9510 - loss: 0.1353 - val_accuracy: 0.8700 - val_loss: 0.4399
# Epoch 96/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 418ms/step - accuracy: 0.9385 - loss: 0.1424 - val_accuracy: 0.8860 - val_loss: 0.3941
# Epoch 97/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 421ms/step - accuracy: 0.9475 - loss: 0.1314 - val_accuracy: 0.8790 - val_loss: 0.4239
# Epoch 98/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 430ms/step - accuracy: 0.9485 - loss: 0.1335 - val_accuracy: 0.8770 - val_loss: 0.3951
# Epoch 99/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 418ms/step - accuracy: 0.9425 - loss: 0.1397 - val_accuracy: 0.8770 - val_loss: 0.4202
# Epoch 100/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 421ms/step - accuracy: 0.9480 - loss: 0.1318 - val_accuracy: 0.7980 - val_loss: 0.9137

# %%
test_model = keras.models.load_model(
    "convnet_from_scratch_with_augmentation.keras"
)
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.8590 - loss: 0.3915
# Test accuracy: 0.859

# %% [markdown]
# ### Using a pretrained model

# %% [markdown]
# #### Feature extraction with a pretrained model

# %%
import keras_hub

conv_base = keras_hub.models.Backbone.from_preset("xception_41_imagenet")

# %%
preprocessor = keras_hub.layers.ImageConverter.from_preset(
    "xception_41_imagenet",
    image_size=(180, 180),
)

# %% [markdown]
# ##### Fast feature extraction without data augmentation

# %%
def get_features_and_labels(dataset):
    all_features = []
    all_labels = []
    for images, labels in dataset:
        preprocessed_images = preprocessor(images)
        features = conv_base.predict(preprocessed_images, verbose=0)
        all_features.append(features)
        all_labels.append(labels)
    return np.concatenate(all_features), np.concatenate(all_labels)

train_features, train_labels = get_features_and_labels(train_dataset)
val_features, val_labels = get_features_and_labels(validation_dataset)
test_features, test_labels = get_features_and_labels(test_dataset)

# %%
train_features.shape
# Out:
# (2000, 6, 6, 2048)

# %%
inputs = keras.Input(shape=(6, 6, 2048))
x = layers.GlobalAveragePooling2D()(inputs)
x = layers.Dense(256, activation="relu")(x)
x = layers.Dropout(0.25)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"],
)

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="feature_extraction.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]
history = model.fit(
    train_features,
    train_labels,
    epochs=10,
    validation_data=(val_features, val_labels),
    callbacks=callbacks,
)
# Out:
# Epoch 1/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9660 - loss: 0.1086 - val_accuracy: 0.9700 - val_loss: 0.0952
# Epoch 2/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9870 - loss: 0.0384 - val_accuracy: 0.9820 - val_loss: 0.0596
# Epoch 3/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9905 - loss: 0.0270 - val_accuracy: 0.9850 - val_loss: 0.0534
# Epoch 4/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9925 - loss: 0.0256 - val_accuracy: 0.9870 - val_loss: 0.0465
# Epoch 5/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9950 - loss: 0.0141 - val_accuracy: 0.9830 - val_loss: 0.0583
# Epoch 6/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9990 - loss: 0.0040 - val_accuracy: 0.9880 - val_loss: 0.0540
# Epoch 7/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9870 - val_loss: 0.0560
# Epoch 8/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9995 - loss: 0.0016 - val_accuracy: 0.9870 - val_loss: 0.0574
# Epoch 9/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 5.5570e-04 - val_accuracy: 0.9870 - val_loss: 0.0604
# Epoch 10/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 4.0131e-04 - val_accuracy: 0.9870 - val_loss: 0.0597

# %%
import matplotlib.pyplot as plt

acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, "r--", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "r--", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
test_model = keras.models.load_model("feature_extraction.keras")
test_loss, test_acc = test_model.evaluate(test_features, test_labels)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9840 - loss: 0.0550
# Test accuracy: 0.984

# %% [markdown]
# ##### Feature extraction together with data augmentation

# %%
import keras_hub

conv_base = keras_hub.models.Backbone.from_preset(
    "xception_41_imagenet",
    trainable=False,
)

# %%
conv_base.trainable = True
len(conv_base.trainable_weights)
# Out:
# 154

# %%
conv_base.trainable = False
len(conv_base.trainable_weights)
# Out:
# 0

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = preprocessor(inputs)
x = conv_base(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.25)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"],
)

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="feature_extraction_with_data_augmentation.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]
history = model.fit(
    augmented_train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks,
)
# Out:
# Epoch 1/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - accuracy: 0.9365 - loss: 0.1510 - val_accuracy: 0.9800 - val_loss: 0.0653
# Epoch 2/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 39s 477ms/step - accuracy: 0.9705 - loss: 0.0900 - val_accuracy: 0.9780 - val_loss: 0.0694
# Epoch 3/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 488ms/step - accuracy: 0.9750 - loss: 0.0792 - val_accuracy: 0.9820 - val_loss: 0.0759
# Epoch 4/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 489ms/step - accuracy: 0.9750 - loss: 0.0735 - val_accuracy: 0.9820 - val_loss: 0.0621
# Epoch 5/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9655 - loss: 0.1052 - val_accuracy: 0.9680 - val_loss: 0.1062
# Epoch 6/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 472ms/step - accuracy: 0.9640 - loss: 0.1097 - val_accuracy: 0.9830 - val_loss: 0.0677
# Epoch 7/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 465ms/step - accuracy: 0.9795 - loss: 0.0635 - val_accuracy: 0.9730 - val_loss: 0.0733
# Epoch 8/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 498ms/step - accuracy: 0.9720 - loss: 0.0790 - val_accuracy: 0.9750 - val_loss: 0.0845
# Epoch 9/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 445ms/step - accuracy: 0.9705 - loss: 0.0894 - val_accuracy: 0.9880 - val_loss: 0.0525
# Epoch 10/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 483ms/step - accuracy: 0.9795 - loss: 0.0656 - val_accuracy: 0.9810 - val_loss: 0.0635
# Epoch 11/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 496ms/step - accuracy: 0.9815 - loss: 0.0581 - val_accuracy: 0.9810 - val_loss: 0.0734
# Epoch 12/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 482ms/step - accuracy: 0.9775 - loss: 0.0626 - val_accuracy: 0.9820 - val_loss: 0.0546
# Epoch 13/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 471ms/step - accuracy: 0.9870 - loss: 0.0314 - val_accuracy: 0.9810 - val_loss: 0.0571
# Epoch 14/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 500ms/step - accuracy: 0.9870 - loss: 0.0343 - val_accuracy: 0.9830 - val_loss: 0.0507
# Epoch 15/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 463ms/step - accuracy: 0.9840 - loss: 0.0511 - val_accuracy: 0.9830 - val_loss: 0.0631
# Epoch 16/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 491ms/step - accuracy: 0.9810 - loss: 0.0600 - val_accuracy: 0.9850 - val_loss: 0.0577
# Epoch 17/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 481ms/step - accuracy: 0.9790 - loss: 0.0679 - val_accuracy: 0.9780 - val_loss: 0.0619
# Epoch 18/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 496ms/step - accuracy: 0.9875 - loss: 0.0366 - val_accuracy: 0.9810 - val_loss: 0.0553
# Epoch 19/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 467ms/step - accuracy: 0.9850 - loss: 0.0403 - val_accuracy: 0.9870 - val_loss: 0.0434
# Epoch 20/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 486ms/step - accuracy: 0.9815 - loss: 0.0485 - val_accuracy: 0.9860 - val_loss: 0.0478
# Epoch 21/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 470ms/step - accuracy: 0.9845 - loss: 0.0436 - val_accuracy: 0.9860 - val_loss: 0.0459
# Epoch 22/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 480ms/step - accuracy: 0.9885 - loss: 0.0395 - val_accuracy: 0.9860 - val_loss: 0.0496
# Epoch 23/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 482ms/step - accuracy: 0.9905 - loss: 0.0328 - val_accuracy: 0.9830 - val_loss: 0.0528
# Epoch 24/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 468ms/step - accuracy: 0.9895 - loss: 0.0325 - val_accuracy: 0.9830 - val_loss: 0.0574
# Epoch 25/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 496ms/step - accuracy: 0.9900 - loss: 0.0347 - val_accuracy: 0.9780 - val_loss: 0.0701
# Epoch 26/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 481ms/step - accuracy: 0.9800 - loss: 0.0494 - val_accuracy: 0.9830 - val_loss: 0.0552
# Epoch 27/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 489ms/step - accuracy: 0.9885 - loss: 0.0303 - val_accuracy: 0.9830 - val_loss: 0.0463
# Epoch 28/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 19s 435ms/step - accuracy: 0.9875 - loss: 0.0310 - val_accuracy: 0.9830 - val_loss: 0.0540
# Epoch 29/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 485ms/step - accuracy: 0.9865 - loss: 0.0352 - val_accuracy: 0.9850 - val_loss: 0.0513
# Epoch 30/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 494ms/step - accuracy: 0.9865 - loss: 0.0371 - val_accuracy: 0.9850 - val_loss: 0.0625

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
test_model = keras.models.load_model(
    "feature_extraction_with_data_augmentation.keras"
)
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 318 variables whereas the saved optimizer has 10 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 357ms/step - accuracy: 0.9800 - loss: 0.0650
# Test accuracy: 0.981

# %% [markdown]
# #### Fine-tuning a pretrained model

# %%
model.compile(
    loss="binary_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=1e-5),
    metrics=["accuracy"],
)

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="fine_tuning.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]
history = model.fit(
    augmented_train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks,
)
# Out:
# Epoch 1/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 37s 896ms/step - accuracy: 0.9924 - loss: 0.0320 - val_accuracy: 0.9850 - val_loss: 0.0541
# Epoch 2/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 506ms/step - accuracy: 0.9878 - loss: 0.0272 - val_accuracy: 0.9860 - val_loss: 0.0527
# Epoch 3/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 724ms/step - accuracy: 0.9909 - loss: 0.0182 - val_accuracy: 0.9840 - val_loss: 0.0529
# Epoch 4/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 448ms/step - accuracy: 0.9915 - loss: 0.0327 - val_accuracy: 0.9850 - val_loss: 0.0530
# Epoch 5/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 717ms/step - accuracy: 0.9880 - loss: 0.0265 - val_accuracy: 0.9850 - val_loss: 0.0534
# Epoch 6/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 477ms/step - accuracy: 0.9896 - loss: 0.0294 - val_accuracy: 0.9850 - val_loss: 0.0535
# Epoch 7/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 457ms/step - accuracy: 0.9886 - loss: 0.0264 - val_accuracy: 0.9850 - val_loss: 0.0533
# Epoch 8/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 438ms/step - accuracy: 0.9937 - loss: 0.0170 - val_accuracy: 0.9850 - val_loss: 0.0534
# Epoch 9/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 467ms/step - accuracy: 0.9896 - loss: 0.0267 - val_accuracy: 0.9860 - val_loss: 0.0520
# Epoch 10/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 485ms/step - accuracy: 0.9939 - loss: 0.0254 - val_accuracy: 0.9860 - val_loss: 0.0518
# Epoch 11/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 703ms/step - accuracy: 0.9962 - loss: 0.0141 - val_accuracy: 0.9860 - val_loss: 0.0518
# Epoch 12/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 710ms/step - accuracy: 0.9904 - loss: 0.0276 - val_accuracy: 0.9860 - val_loss: 0.0520
# Epoch 13/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 454ms/step - accuracy: 0.9942 - loss: 0.0158 - val_accuracy: 0.9860 - val_loss: 0.0519
# Epoch 14/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 19s 573ms/step - accuracy: 0.9945 - loss: 0.0222 - val_accuracy: 0.9850 - val_loss: 0.0523
# Epoch 15/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 697ms/step - accuracy: 0.9897 - loss: 0.0321 - val_accuracy: 0.9860 - val_loss: 0.0516
# Epoch 16/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 482ms/step - accuracy: 0.9918 - loss: 0.0206 - val_accuracy: 0.9850 - val_loss: 0.0513
# Epoch 17/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 745ms/step - accuracy: 0.9882 - loss: 0.0246 - val_accuracy: 0.9860 - val_loss: 0.0508
# Epoch 18/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 450ms/step - accuracy: 0.9890 - loss: 0.0396 - val_accuracy: 0.9850 - val_loss: 0.0509
# Epoch 19/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 472ms/step - accuracy: 0.9906 - loss: 0.0350 - val_accuracy: 0.9850 - val_loss: 0.0508
# Epoch 20/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 717ms/step - accuracy: 0.9898 - loss: 0.0306 - val_accuracy: 0.9860 - val_loss: 0.0506
# Epoch 21/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 479ms/step - accuracy: 0.9943 - loss: 0.0170 - val_accuracy: 0.9850 - val_loss: 0.0506
# Epoch 22/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 458ms/step - accuracy: 0.9888 - loss: 0.0253 - val_accuracy: 0.9850 - val_loss: 0.0508
# Epoch 23/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 704ms/step - accuracy: 0.9889 - loss: 0.0281 - val_accuracy: 0.9850 - val_loss: 0.0506
# Epoch 24/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 470ms/step - accuracy: 0.9927 - loss: 0.0199 - val_accuracy: 0.9850 - val_loss: 0.0506
# Epoch 25/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 482ms/step - accuracy: 0.9900 - loss: 0.0319 - val_accuracy: 0.9860 - val_loss: 0.0500
# Epoch 26/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 435ms/step - accuracy: 0.9903 - loss: 0.0278 - val_accuracy: 0.9850 - val_loss: 0.0503
# Epoch 27/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 700ms/step - accuracy: 0.9924 - loss: 0.0190 - val_accuracy: 0.9860 - val_loss: 0.0505
# Epoch 28/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 725ms/step - accuracy: 0.9915 - loss: 0.0236 - val_accuracy: 0.9840 - val_loss: 0.0515
# Epoch 29/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 708ms/step - accuracy: 0.9956 - loss: 0.0167 - val_accuracy: 0.9860 - val_loss: 0.0502
# Epoch 30/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 463ms/step - accuracy: 0.9948 - loss: 0.0198 - val_accuracy: 0.9870 - val_loss: 0.0493

# %%
model = keras.models.load_model("fine_tuning.keras")
test_loss, test_acc = model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 322ms/step - accuracy: 0.9838 - loss: 0.0685
# Test accuracy: 0.985
